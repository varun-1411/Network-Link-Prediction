# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('../data/test_with_features.csv')

# %%
# plot distributution of each variable
df_test.hist(figsize=(20,20))
plt.show()

# %%
plt.hist(df_test['outdegree_from'], bins=10)
plt.xlim(0, 40000)
# Out:
# (0.0, 40000.0)

# %%
plt.hist(df_test['indegree_To'], bins=10)
plt.xlim(0, 3000)
# Out:
# (0.0, 3000.0)

# %%
df_to = df_test[df_test['indegree_To'] < 1100]

# %%
df_to.shape
# Out:
# (1951, 13)

# %%
plt.hist(df_to['indegree_To'], bins=10)
plt.xlim(0, 2000)
# Out:
# (0.0, 2000.0)
